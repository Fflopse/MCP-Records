# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['premium_plus', 'premium', 'builder', 'player', 'developer', 'VIP', 'content', 'supporter', 'owner', 'moderator', 'translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:
            mp_stats = data['stats']['mp']['global']
            
            # Map API fields to the format your original script expected
            stat_mapping = {
                'Siege': mp_stats.get('wins', 0),
                'Minispiel-Siege': mp_stats.get('minigame_wins', 0),
                'Spiele': mp_stats.get('games', 0),
                'Minispiele': mp_stats.get('minigames', 0),
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank', 0)
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Processing 242 players...
# Found 242 unique UUIDs
# Progress: 1/242 - KakaMC
# Progress: 2/242 - Dat_Klan
# Progress: 3/242 - Flitzi_Dino
# Progress: 4/242 - GamemasterNiki
# Progress: 5/242 - N3XV
# Progress: 235/242 - Bikop
# Progress: 236/242 - SWLegende
# Progress: 237/242 - Failed to get name for e0b1e96c-4659-4b5f-a074-355b42da4714
# Progress: 238/242 - Failed to get name for 87ae2b9d-2f07-4b22-96bd-4f6a79853920
# Progress: 239/242 - Failed to get name for 072ea26fab9149eaac98660626a16515
# Progress: 240/242 - Failed to get name for 6632946e-6cbd-405a-950b-a25b6984e77a
# Progress: 241/242 - yachayubin
# Progress: 242/242 - Failed to get name for 9b3bb492-3047-4bd4-9a11-c9a810bf89ab
# Warning: Keeping old name 'Kanickelul' - couldn't fetch current name
# Warning: Keeping old name 'yzvm' - couldn't fetch current name
# Warning: Keeping old name 'Shiewk' - couldn't fetch current name
# Warning: Keeping old name 'lvlaurin' - couldn't fetch current name
# Warning: Keeping old name 'Snitcherella' - couldn't fetch current name
# Warning: Keeping old name 'chrisihalt' - couldn't fetch current name
# Warning: Keeping old name 'BusinessBent' - couldn't fetch current name
# Warning: Keeping old name 'Luis_XYZ' - couldn't fetch current name
# Warning: Keeping old name 'Highsay' - couldn't fetch current name
# Warning: Keeping old name 'HeIsJustAPoorBoy' - couldn't fetch current name
# Warning: Keeping old name 'Sackkerl' - couldn't fetch current name
# Warning: Keeping old name 'PixlNight' - couldn't fetch current name
# Warning: Keeping old name 'Janne4k' - couldn't fetch current name
# Warning: Keeping old name 'bawskey' - couldn't fetch current name
# Warning: Keeping old name 'dossantosaveiro_' - couldn't fetch current name
# Warning: Keeping old name 'ScreamingBlatz' - couldn't fetch current name
# Warning: Keeping old name 'Ex4cted' - couldn't fetch current name
# Warning: Keeping old name 'LeWi_100' - couldn't fetch current name
# Warning: Keeping old name '_Waldi_' - couldn't fetch current name
# Warning: Keeping old name 'ByNetherdude' - couldn't fetch current name
# Warning: Keeping old name 'SiLoHB' - couldn't fetch current name
# Warning: Keeping old name 'DaVinci_Son' - couldn't fetch current name
# Warning: Keeping old name 'Sey__' - couldn't fetch current name
# Warning: Keeping old name 'Kyuudo' - couldn't fetch current name
# Warning: Keeping old name 'Jan2220' - couldn't fetch current name
# Warning: Keeping old name 'crocodile1870' - couldn't fetch current name
# Warning: Keeping old name 'StaudammAusHolz' - couldn't fetch current name
# Warning: Keeping old name 'SpeckyCut' - couldn't fetch current name
# Warning: Keeping old name 'PedroZockt' - couldn't fetch current name
# Warning: Keeping old name 'GrafikKatze' - couldn't fetch current name
# Warning: Keeping old name 'T_Niko_T' - couldn't fetch current name
# Warning: Keeping old name 'Falke23_5' - couldn't fetch current name
# Warning: Keeping old name 'Lingex' - couldn't fetch current name
# Warning: Keeping old name 'Fflopse' - couldn't fetch current name
# Warning: Keeping old name 'Keenaai' - couldn't fetch current name
# Warning: Keeping old name 'Bartschii' - couldn't fetch current name
# Warning: Keeping old name 'loukrativ' - couldn't fetch current name
# Warning: Keeping old name 'Morittz' - couldn't fetch current name
# Warning: Keeping old name 'SecretAgent_K' - couldn't fetch current name
# Warning: Keeping old name 'NanamiElvi' - couldn't fetch current name
# Warning: Keeping old name 'Ungluecklicher' - couldn't fetch current name
# Warning: Keeping old name 'Pluto28' - couldn't fetch current name
# Warning: Keeping old name 'Julius16' - couldn't fetch current name
# Warning: Keeping old name 'shellny' - couldn't fetch current name
# Warning: Keeping old name 'toxicplace' - couldn't fetch current name
# Warning: Keeping old name 'Mansuni' - couldn't fetch current name
# Warning: Keeping old name 'IchHolzDichWeg' - couldn't fetch current name
# Warning: Keeping old name 'destr0yed_' - couldn't fetch current name
# Warning: Keeping old name 'Falke_01' - couldn't fetch current name
# Warning: Keeping old name 'Wolkenfarmer' - couldn't fetch current name
# Warning: Keeping old name 'FrozenNoah' - couldn't fetch current name
# Warning: Keeping old name 'GermanPie' - couldn't fetch current name
# Warning: Keeping old name 'MaxMitMaulkorb' - couldn't fetch current name
# Warning: Keeping old name 'FlyingKyubi' - couldn't fetch current name
# Warning: Keeping old name 'Odlaa' - couldn't fetch current name
# Warning: Keeping old name 'ArthurAlchemist' - couldn't fetch current name
# Warning: Keeping old name 'TheKillerisback' - couldn't fetch current name
# Warning: Keeping old name 'Dubbly' - couldn't fetch current name
# Warning: Keeping old name 'D4rkCookie' - couldn't fetch current name
# Warning: Keeping old name 'PumiTheCat' - couldn't fetch current name
# Warning: Keeping old name 'LucaaOn' - couldn't fetch current name
# Warning: Keeping old name 'BastiGHG' - couldn't fetch current name
# Warning: Keeping old name 'RyanxCole' - couldn't fetch current name
# Warning: Keeping old name 'RasenLP' - couldn't fetch current name
# Warning: Keeping old name 'BauHD' - couldn't fetch current name
# Warning: Keeping old name 'Phoenix3000' - couldn't fetch current name
# Warning: Keeping old name 'Nor_Malo' - couldn't fetch current name
# Warning: Keeping old name 'zLachs' - couldn't fetch current name
# Warning: Keeping old name 'AnzeigeGehtRaus' - couldn't fetch current name
# Warning: Keeping old name 'linastunna' - couldn't fetch current name
# Warning: Keeping old name 'Otronix' - couldn't fetch current name
# Warning: Keeping old name 'kfc_man069' - couldn't fetch current name
# Warning: Keeping old name 'Joel_the_king' - couldn't fetch current name
# Warning: Keeping old name 'Kklopse' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress: 100%|██████████| 242/242 [02:34<00:00,  1.56player/s, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
# Exported Premium+.txt
# Exported Premium.txt
# Exported Bauteam.txt
# Exported Spieler.txt
# Exported Entwickler.txt
# Exported VIP.txt
# Exported Content.txt
# Exported Supporter.txt
# Exported Owner.txt
# Exported Moderator.txt
# Exported Translator.txt
