# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:

            mp_stats = data['stats']['mp']['global']
            
            # Calculate win rates
            wins = mp_stats.get('wins', 0)
            games = mp_stats.get('games', 0)
            minigame_wins = mp_stats.get('minigame_wins', 0)
            minigames = mp_stats.get('minigames', 0)
            
            winrate = round((wins / games * 100), 2) if games > 0 else 0
            minigame_winrate = round((minigame_wins / minigames * 100), 2) if minigames > 0 else 0
            
            stat_mapping = {
                'Gewonnene Spiele': wins,
                'Gewonnene Minispiele': minigame_wins,
                'Gespielte Spiele': games,
                'Gespielte Minispiele': minigames,
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank_points', 0),
                'Winrate %': winrate,
                'Minigame Winrate %': minigame_winrate
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Processing 242 players...
# Found 242 unique UUIDs
# Progress: 1/242 - AnzeigeGehtRaus
# Progress: 2/242 - DrSpeed06
(Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x103766220>: Failed to establish a new connection: [Errno 65] No route to host'))
# Error for UUID ea57e4b4-6c38-454e-928b-efe6c9625794: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/ea57e4b4-6c38-454e-928b-efe6c9625794 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1037c62b0>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 233/242 - Failed to get name for 970ab36f-1279-458c-b1c9-3668fba62d95
# Progress: 234/242 - Failed to get name for ea57e4b4-6c38-454e-928b-efe6c9625794
# Error for UUID 6c8e1d6a-963b-4eff-a867-e1b8b93f04d5: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/6c8e1d6a-963b-4eff-a867-e1b8b93f04d5 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1037c6dc0>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 235/242 - Failed to get name for 6c8e1d6a-963b-4eff-a867-e1b8b93f04d5
# Error for UUID 6a799e93-bcf1-4267-ba16-b628b5a7720a: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/6a799e93-bcf1-4267-ba16-b628b5a7720a (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x103e51b50>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 236/242 - Failed to get name for 6a799e93-bcf1-4267-ba16-b628b5a7720a
# Error for UUID f66ec32d-2cea-4eaf-b4f9-e0438c905679: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/f66ec32d-2cea-4eaf-b4f9-e0438c905679 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1037c6100>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 237/242 - Failed to get name for f66ec32d-2cea-4eaf-b4f9-e0438c905679
# Error for UUID 95b00fda-dee1-4103-9397-3483a29d871b: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/95b00fda-dee1-4103-9397-3483a29d871b (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x10378b5e0>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 238/242 - Failed to get name for 95b00fda-dee1-4103-9397-3483a29d871b
# Error for UUID 59671526-dc07-41d4-b520-923553cdde6e: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/59671526-dc07-41d4-b520-923553cdde6e (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x1032eba00>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 239/242 - Failed to get name for 59671526-dc07-41d4-b520-923553cdde6e
# Error for UUID 5fd819fe-8799-44e4-a6c9-273b84e8a555: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/5fd819fe-8799-44e4-a6c9-273b84e8a555 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x103e5e400>: Failed to establish a new connection: [Errno 65] No route to host'))
# Progress: 240/242 - Failed to get name for 5fd819fe-8799-44e4-a6c9-273b84e8a555
# Progress: 241/242 - agowskyy
# Progress: 242/242 - Sackkerl
# Warning: Keeping old name 'Kanickelul' - couldn't fetch current name
# Warning: Keeping old name 'yzvm' - couldn't fetch current name
# Warning: Keeping old name 'marbrueck' - couldn't fetch current name
# Warning: Keeping old name 'Sower_' - couldn't fetch current name
# Warning: Keeping old name 'Snitcherella' - couldn't fetch current name
# Warning: Keeping old name 'BusinessBent' - couldn't fetch current name
# Warning: Keeping old name 'Freeeedom' - couldn't fetch current name
# Warning: Keeping old name '2wc' - couldn't fetch current name
# Warning: Keeping old name 'Oronor' - couldn't fetch current name
# Warning: Keeping old name 'Luis_XYZ' - couldn't fetch current name
# Warning: Keeping old name 'TheBreadHD' - couldn't fetch current name
# Warning: Keeping old name 'M0orey_0' - couldn't fetch current name
# Warning: Keeping old name 'Joy_8oy' - couldn't fetch current name
# Warning: Keeping old name 'Chander24' - couldn't fetch current name
# Warning: Keeping old name 'frutigall' - couldn't fetch current name
# Warning: Keeping old name 'Umgfoin' - couldn't fetch current name
# Warning: Keeping old name 'HeIsJustAPoorBoy' - couldn't fetch current name
# Warning: Keeping old name 'revolverz' - couldn't fetch current name
# Warning: Keeping old name 'Sebi1801' - couldn't fetch current name
# Warning: Keeping old name 'PixlNight' - couldn't fetch current name
# Warning: Keeping old name 'bawskey' - couldn't fetch current name
# Warning: Keeping old name 'Lubottus' - couldn't fetch current name
# Warning: Keeping old name 'ffawks' - couldn't fetch current name
# Warning: Keeping old name 'Dokkkkko' - couldn't fetch current name
# Warning: Keeping old name 'crocodile1870' - couldn't fetch current name
# Warning: Keeping old name 'StaudammAusHolz' - couldn't fetch current name
# Warning: Keeping old name 'PedroZockt' - couldn't fetch current name
# Warning: Keeping old name 'GrafikKatze' - couldn't fetch current name
# Warning: Keeping old name 'ForceFox' - couldn't fetch current name
# Warning: Keeping old name 'Harold_Sensemann' - couldn't fetch current name
# Warning: Keeping old name 'ZweitesIch' - couldn't fetch current name
# Warning: Keeping old name 'SecretAgent_K' - couldn't fetch current name
# Warning: Keeping old name 'SatzdesPytag0ras' - couldn't fetch current name
# Warning: Keeping old name 'Juti0n' - couldn't fetch current name
# Warning: Keeping old name 'shellny' - couldn't fetch current name
# Warning: Keeping old name 'toxicplace' - couldn't fetch current name
# Warning: Keeping old name 'Lutorix' - couldn't fetch current name
# Warning: Keeping old name 'Lennart0911' - couldn't fetch current name
# Warning: Keeping old name 'HerosHD' - couldn't fetch current name
# Warning: Keeping old name 'FlyingAutismus' - couldn't fetch current name
# Warning: Keeping old name 'Steavn' - couldn't fetch current name
# Warning: Keeping old name '_Einfallslos_' - couldn't fetch current name
# Warning: Keeping old name 'EinfachEazy' - couldn't fetch current name
# Warning: Keeping old name 'FrozenNoah' - couldn't fetch current name
# Warning: Keeping old name 'SpinCrafter' - couldn't fetch current name
# Warning: Keeping old name 'Carl1_1' - couldn't fetch current name
# Warning: Keeping old name 'Bikop' - couldn't fetch current name
# Warning: Keeping old name 'Lord_Weibull' - couldn't fetch current name
# Warning: Keeping old name 'D4rkCookie' - couldn't fetch current name
# Warning: Keeping old name 'Sthyq' - couldn't fetch current name
# Warning: Keeping old name 'RyanxCole' - couldn't fetch current name
# Warning: Keeping old name 'y9nic' - couldn't fetch current name
# Warning: Keeping old name 'JOW24' - couldn't fetch current name
# Warning: Keeping old name 'GingerTeddy' - couldn't fetch current name
# Warning: Keeping old name 'redbrll' - couldn't fetch current name
# Warning: Keeping old name 'qriezmannsOpa' - couldn't fetch current name
# Warning: Keeping old name 'Lelouch610' - couldn't fetch current name
# Warning: Keeping old name 'Phoenix3000' - couldn't fetch current name
# Warning: Keeping old name 'kfc_man069' - couldn't fetch current name
# Warning: Keeping old name 'Kklopse' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress:  63%|██████▎   | 152/242 [05:00<02:16,  1.52s/player, last_player=Shiewk, last_rank=Premium]          2025-07-07 23:44:31,966 - ERROR - Error fetching data for SiLoHB: HTTPSConnectionPool(host='api.cytooxien.de', port=443): Read timed out. (read timeout=10)
# Fetching Progress: 100%|██████████| 242/242 [06:51<00:00,  1.70s/player, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
