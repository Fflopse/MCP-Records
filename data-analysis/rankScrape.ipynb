# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:

            mp_stats = data['stats']['mp']['global']
            
            # Calculate win rates
            wins = mp_stats.get('wins', 0)
            games = mp_stats.get('games', 0)
            minigame_wins = mp_stats.get('minigame_wins', 0)
            minigames = mp_stats.get('minigames', 0)
            
            winrate = round((wins / games * 100), 2) if games > 0 else 0
            minigame_winrate = round((minigame_wins / minigames * 100), 2) if minigames > 0 else 0
            
            stat_mapping = {
                'Gewonnene Spiele': wins,
                'Gewonnene Minispiele': minigame_wins,
                'Gespielte Spiele': games,
                'Gespielte Minispiele': minigames,
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank_points', 0),
                'Winrate %': winrate,
                'Minigame Winrate %': minigame_winrate
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Progress: 208/242 - Failed to get name for 6c6fea3c-8aec-4b3d-88d1-fc9598a5b1d0
# Progress: 209/242 - Failed to get name for afc57a02e89d49b7b210529cf55a8034
# Progress: 210/242 - Dat_Klan
# Progress: 211/242 - Failed to get name for c0228b6e-178b-49e6-8986-f9f4df0580ce
# Progress: 212/242 - Gryzes
# Progress: 213/242 - Failed to get name for 6fcd4e1c-1506-4453-b587-7ba923d41a64
# Progress: 214/242 - Failed to get name for a1a2542d096d442d89d9c310f105986d
# Progress: 215/242 - Failed to get name for 1786d729-a427-4351-8b34-e6dc3506af2b
# Progress: 216/242 - Failed to get name for 6e320d20-c94b-4995-836d-807de85df100
# Progress: 217/242 - Picutar
# Progress: 218/242 - EinfachEazy
# Progress: 219/242 - Failed to get name for 813e65c3-9b20-418a-a00f-3c376e9cb674
# Progress: 220/242 - xX_Dima_ggg_Xx6
# Progress: 221/242 - Failed to get name for f4fc6358-ee9a-4507-9cde-548347ba2222
# Progress: 222/242 - Mvsk_
# Progress: 223/242 - Failed to get name for d6d3a94e-fecd-424e-928b-5714cabdc5f6
# Progress: 224/242 - Failed to get name for 79bc0af767d3497199ff8e5509527de3
# Progress: 225/242 - Persidieus
# Progress: 226/242 - Failed to get name for 49473f00-42a0-4d00-b969-388050a744ea
# Progress: 227/242 - Failed to get name for 87ae2b9d-2f07-4b22-96bd-4f6a79853920
# Progress: 228/242 - Gerrygames
# Progress: 229/242 - jimmi4Life
# Progress: 230/242 - D4rkCookie
# Progress: 231/242 - yiiq
# Progress: 232/242 - Failed to get name for 31f97bd5-5f99-43b0-8b77-848f2aaf5af9
# Progress: 233/242 - Failed to get name for bc71335b-1e4b-4a6d-a8e4-64862069790f
# Progress: 234/242 - Failed to get name for 99f9fca2-7bff-4bf4-a96f-58520c3e3788
# Progress: 235/242 - Failed to get name for f2c586ef-c2f6-4d99-8f3a-235df2694abc
# Progress: 236/242 - Tomiokey
# Progress: 237/242 - Failed to get name for e25afc49-2e26-4c32-8928-7a42e7530a54
# Progress: 238/242 - Failed to get name for 7b540bd2-5ee4-4b51-b114-f905fd122558
# Progress: 239/242 - Failed to get name for 3e1295ed-b029-4403-b3c7-409eceba945c
# Progress: 240/242 - Axollotel
# Progress: 241/242 - JOW24
# Progress: 242/242 - Failed to get name for 00bee981-8ddd-422d-892d-8c57aef51150
# Warning: Keeping old name 'DerAutist' - couldn't fetch current name
# Warning: Keeping old name 'deadfiight' - couldn't fetch current name
# Warning: Keeping old name 'chrisihalt' - couldn't fetch current name
# Warning: Keeping old name 'Freeeedom' - couldn't fetch current name
# Warning: Keeping old name 'Oronor' - couldn't fetch current name
# Warning: Keeping old name 'TheBreadHD' - couldn't fetch current name
# Warning: Keeping old name 'Joy_8oy' - couldn't fetch current name
# Warning: Keeping old name 'byTobi' - couldn't fetch current name
# Warning: Keeping old name 'KakaMC' - couldn't fetch current name
# Warning: Keeping old name 'Highsay' - couldn't fetch current name
# Warning: Keeping old name 'Sackkerl' - couldn't fetch current name
# Warning: Keeping old name 'Wissender' - couldn't fetch current name
# Warning: Keeping old name 'ScreamingBlatz' - couldn't fetch current name
# Warning: Keeping old name 'Sey__' - couldn't fetch current name
# Warning: Keeping old name 'Kyuudo' - couldn't fetch current name
# Warning: Keeping old name 'Martomias' - couldn't fetch current name
# Warning: Keeping old name 'SpeckyCut' - couldn't fetch current name
# Warning: Keeping old name 'LordAlexos' - couldn't fetch current name
# Warning: Keeping old name 'HerrDante' - couldn't fetch current name
# Warning: Keeping old name 'xX_Masha_ggg_Xx9' - couldn't fetch current name
# Warning: Keeping old name 'Raefinzs' - couldn't fetch current name
# Warning: Keeping old name 'camman18YT' - couldn't fetch current name
# Warning: Keeping old name 'xBaumeisterin' - couldn't fetch current name
# Warning: Keeping old name 'ForceFox' - couldn't fetch current name
# Warning: Keeping old name 'Bartschii' - couldn't fetch current name
# Warning: Keeping old name 'demiu' - couldn't fetch current name
# Warning: Keeping old name 'Morittz' - couldn't fetch current name
# Warning: Keeping old name 'G0at3D' - couldn't fetch current name
# Warning: Keeping old name 'SecretAgent_K' - couldn't fetch current name
# Warning: Keeping old name 'SatzdesPytag0ras' - couldn't fetch current name
# Warning: Keeping old name 'vKito' - couldn't fetch current name
# Warning: Keeping old name 'toxicplace' - couldn't fetch current name
# Warning: Keeping old name 'Mansuni' - couldn't fetch current name
# Warning: Keeping old name 'DrSpeed06' - couldn't fetch current name
# Warning: Keeping old name 'Tammywood' - couldn't fetch current name
# Warning: Keeping old name 'FlyingAutismus' - couldn't fetch current name
# Warning: Keeping old name 'Steavn' - couldn't fetch current name
# Warning: Keeping old name '_Einfallslos_' - couldn't fetch current name
# Warning: Keeping old name 'Bikop' - couldn't fetch current name
# Warning: Keeping old name 'WuschigesEtwas' - couldn't fetch current name
# Warning: Keeping old name 'Lord_Weibull' - couldn't fetch current name
# Warning: Keeping old name 'Squashgitter333' - couldn't fetch current name
# Warning: Keeping old name 'Bikoop' - couldn't fetch current name
# Warning: Keeping old name 'y9nic' - couldn't fetch current name
# Warning: Keeping old name 'RasenLP' - couldn't fetch current name
# Warning: Keeping old name 'BauHD' - couldn't fetch current name
# Warning: Keeping old name 'Nervigerr' - couldn't fetch current name
# Warning: Keeping old name 'rotmann2' - couldn't fetch current name
# Warning: Keeping old name 'redbrll' - couldn't fetch current name
# Warning: Keeping old name 'qriezmannsOpa' - couldn't fetch current name
# Warning: Keeping old name 'SWLegende' - couldn't fetch current name
# Warning: Keeping old name 'zLachs' - couldn't fetch current name
# Warning: Keeping old name 'AnzeigeGehtRaus' - couldn't fetch current name
# Warning: Keeping old name 'Joel_the_king' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress: 100%|██████████| 242/242 [02:45<00:00,  1.46player/s, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
