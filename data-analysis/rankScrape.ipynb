# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:

            mp_stats = data['stats']['mp']['global']
            
            # Calculate win rates
            wins = mp_stats.get('wins', 0)
            games = mp_stats.get('games', 0)
            minigame_wins = mp_stats.get('minigame_wins', 0)
            minigames = mp_stats.get('minigames', 0)
            
            winrate = round((wins / games * 100), 2) if games > 0 else 0
            minigame_winrate = round((minigame_wins / minigames * 100), 2) if minigames > 0 else 0
            
            stat_mapping = {
                'Gewonnene Spiele': wins,
                'Gewonnene Minispiele': minigame_wins,
                'Gespielte Spiele': games,
                'Gespielte Minispiele': minigames,
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank_points', 0),
                'Winrate %': winrate,
                'Minigame Winrate %': minigame_winrate
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"
# Out:
# /Users/eliasmb/MCP-Records/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Processing 242 players...
# Found 242 unique UUIDs
# Progress: 1/242 - BastiGHG
# Progress: 2/242 - DrSpeed06
# Progress: 3/242 - GlowyDusk
# Progress: 4/242 - ReichesBrot
# Progress: 5/242 - SB387
# Progress: 6/242 - NotLennart
# Progress: 7/242 - AnzeigeGehtRaus
# Progress: 8/242 - JOW23
# Progress: 9/242 - Shiewk
# Progress: 10/242 - Lingex
# Progress: 11/242 - Gryzes
# Progress: 12/242 - ByNetherdude
# Progress: 13/242 - Schmaarek
# Progress: 14/242 - xiooh
# Progress: 15/242 - LucaaOn
# Progress: 16/242 - WuschigesEtwas
# Progress: 17/242 - Luxemburq
# Progress: 18/242 - Hyxeed
# Progress: 19/242 - Grapfen
# Progress: 20/242 - Cytoox
# Progress: 21/242 - 2B9
# Progress: 22/242 - Gestimus
# Progress: 23/242 - OutcroYoutube
# Progress: 24/242 - Morittz
# Progress: 25/242 - FluffyDragon2007
# Progress: 26/242 - Nor_Malo
# Progress: 27/242 - Wolkenfarmer
# Progress: 28/242 - Navex
# Progress: 29/242 - Sey__
# Progress: 30/242 - Kyuudo
# Progress: 31/242 - zBro
# Progress: 32/242 - SmartyxD
# Progress: 33/242 - Gfrasti
# Progress: 34/242 - h4nnes
# Progress: 35/242 - T_Niko_T
# Progress: 36/242 - Acidey
# Progress: 37/242 - PumiTheCat
# Progress: 38/242 - M0osebumps
# Progress: 39/242 - twitchparaskiill
# Progress: 40/242 - Picutar
# Progress: 41/242 - 20LeRe10
# Progress: 42/242 - Mansuni
# Progress: 43/242 - WshPasie
# Progress: 44/242 - LordAlexos
# Progress: 45/242 - TheFabo
# Progress: 46/242 - Gerrygames
# Progress: 47/242 - SpinCrafter
# Progress: 48/242 - cheesecake2901
# Progress: 49/242 - swiffle
# Progress: 50/242 - CladyNoClip_
# Progress: 51/242 - LilFueller
# Progress: 52/242 - lizsyy
# Progress: 53/242 - MoZadaTV
# Progress: 54/242 - KINT0
# Progress: 55/242 - ArthurAlchemist
# Progress: 56/242 - Persidieus
# Progress: 57/242 - LeWi_100
# Progress: 58/242 - KMaxN
# Progress: 59/242 - destr0yed_
# Progress: 60/242 - GeneralEnte06
# Progress: 61/242 - Gobo9
# Progress: 62/242 - miridis41
# Progress: 63/242 - Tammywood
# Progress: 64/242 - FlyingKyubi
# Progress: 65/242 - DieserBear
# Progress: 66/242 - Teesily
# Progress: 67/242 - Ex4cted
# Progress: 68/242 - Gummibearchen
# Progress: 69/242 - VendasTM
# Progress: 70/242 - chrisihalt
# Progress: 71/242 - Dat_Klan
# Progress: 72/242 - jimmi4Life
# Progress: 73/242 - _n3d
# Progress: 74/242 - Wissender
# Progress: 75/242 - Kanickelul
# Progress: 76/242 - MrNulfred
# Progress: 77/242 - Bikop
# Progress: 78/242 - NiklasMoWo
# Progress: 79/242 - Stockinqs
# Progress: 80/242 - SiLoHB
# Progress: 81/242 - Highsay
# Progress: 82/242 - SpeckyCut
# Progress: 83/242 - Tomiokey
# Progress: 84/242 - demiu
# Progress: 85/242 - xd_Maiky
# Progress: 86/242 - Bartschii
# Progress: 87/242 - byTobi
# Progress: 88/242 - Flitzi_Dino
# Progress: 89/242 - Nervigerr
# Progress: 90/242 - CML_Justin
# Progress: 91/242 - Allooy
# Progress: 92/242 - cxl1lo
# Progress: 93/242 - MaxOnTheRoad
# Progress: 94/242 - juvona
# Progress: 95/242 - vKito
# Progress: 96/242 - xBaumeisterin
# Progress: 97/242 - Muniix
# Progress: 98/242 - xX_Masha_ggg_Xx9
# Progress: 99/242 - JayMinInSane
# Progress: 100/242 - Jan2220
# Progress: 101/242 - Feinberg
# Progress: 102/242 - dossantosaveiro_
# Progress: 103/242 - G0at3D
# Progress: 104/242 - SWLegende
# Progress: 105/242 - RasenLP
# Progress: 106/242 - GermanPie
# Progress: 107/242 - Janne4k
# Progress: 108/242 - Bildungsarten
# Progress: 109/242 - DerAutist
# Progress: 110/242 - BauHD
# Progress: 111/242 - Raefinzs
# Progress: 112/242 - Mincheeen
# Progress: 113/242 - Bikoop
# Progress: 114/242 - La_meleagro
# Progress: 115/242 - LeMetin_
# Progress: 116/242 - Axollotel
# Progress: 117/242 - Mvsk_
# Progress: 118/242 - unausgesprochen
# Progress: 119/242 - Vanillinchen
# Progress: 120/242 - zLachs
# Progress: 121/242 - marbrueck
# Progress: 122/242 - HerrDante
# Progress: 123/242 - Ninivee
# Progress: 124/242 - Dubbly
# Progress: 125/242 - TheKillerisback
# Progress: 126/242 - YBCM
# Progress: 127/242 - camman18YT
# Progress: 128/242 - DaVinci_Son
# Progress: 129/242 - medisant
# Progress: 130/242 - loukrativ
# Progress: 131/242 - Juti0n
# Progress: 132/242 - ForceFox
# Progress: 133/242 - _Einfallslos_
# Progress: 134/242 - Failed to get name for 694c15e2-2196-425c-bf82-490a7b8eec46
# Progress: 135/242 - deadfiight
# Progress: 136/242 - linastunna
# Progress: 137/242 - Martomias
# Progress: 138/242 - _Waldi_
# Progress: 139/242 - lvlaurin
# Progress: 140/242 - MaxMitMaulkorb
# Progress: 141/242 - Scuprum
# Progress: 142/242 - PolizeiDreamy
# Progress: 143/242 - Wienerisch
# Progress: 144/242 - Laaaachs
# Progress: 145/242 - yachayubin
# Progress: 146/242 - yiiq
# Progress: 147/242 - toxicplace
# Progress: 148/242 - Snitcherella
# Progress: 149/242 - Otronix
# Progress: 150/242 - Julius16
# Progress: 151/242 - IchHolzDichWeg
# Progress: 152/242 - KakaMC
# Progress: 153/242 - 2wc
# Progress: 154/242 - Failed to get name for db3f16e5-bd56-4de3-a258-bd4c1d856096
# Progress: 155/242 - Ungluecklicher
# Progress: 156/242 - DarkCobweb
# Progress: 157/242 - Kopfradio
# Progress: 158/242 - NanamiElvi
# Progress: 159/242 - WirdNichtGeladen
# Progress: 160/242 - BunnyKiko
# Progress: 161/242 - Falke_01
# Progress: 162/242 - Joel_the_king
# Progress: 163/242 - musi1999
# Progress: 164/242 - xIForgotMySkill
# Progress: 165/242 - Failed to get name for 4888255f-9e96-4f8d-bbb7-1140e848cc73
# Progress: 166/242 - Squashgitter333
# Progress: 167/242 - PixlNight
# Progress: 168/242 - SatzdesPytag0ras
# Progress: 169/242 - yzvm
# Progress: 170/242 - Odlaa
# Progress: 171/242 - Fflopse
# Progress: 172/242 - sirmigorius
# Progress: 173/242 - N3XV
# Progress: 174/242 - GamemasterNiki
# Progress: 175/242 - lolisamakun
# Progress: 176/242 - Joe3346
# Progress: 177/242 - Falke23_5
# Progress: 178/242 - xX_Dima_ggg_Xx6
# Progress: 179/242 - NewNormal0947
# Progress: 180/242 - Txlentierter
# Progress: 181/242 - Failed to get name for 913043a4-b351-45ad-8511-f8bf1d909f30
# Progress: 182/242 - Simlll
# Progress: 183/242 - Vacted
# Progress: 184/242 - lolisamasan
# Progress: 185/242 - cediiiiii_10
# Progress: 186/242 - Failed to get name for 4a61927f-2fd6-4c7d-9d95-d9197f774488
# Progress: 187/242 - Kokochampo
# Progress: 188/242 - Keenaai
# Progress: 189/242 - Pluto28
# Progress: 190/242 - rotmann2
# Progress: 191/242 - Failed to get name for 36712959-4a90-4e69-b62b-2867e8045bda
# Progress: 192/242 - Anni808
# Progress: 193/242 - ScreamingBlatz
# Progress: 194/242 - Ritokii
# Progress: 195/242 - Seemops_8
# Progress: 196/242 - agowskyy
# Progress: 197/242 - Sackkerl
# Progress: 198/242 - Lord_Weibull
# Progress: 199/242 - crocodile1870
# Progress: 200/242 - Carl1_1
# Progress: 201/242 - Joy_8oy
# Progress: 202/242 - M0orey_0
# Progress: 203/242 - Phoenix3000
# Progress: 204/242 - Sebi1801
# Progress: 205/242 - Failed to get name for 54c48894-ddde-408e-b877-16db7562bfe1
# Progress: 206/242 - bawskey
# Progress: 207/242 - redbrll
# Progress: 208/242 - qriezmannsOpa
# Progress: 209/242 - Failed to get name for 6976dc73-a8ad-4f4d-8b15-466c52b784a1
# Progress: 210/242 - StaudammAusHolz
# Progress: 211/242 - ZweitesIch
# Progress: 212/242 - FlyingAutismus
# Progress: 213/242 - shellny
# Progress: 214/242 - HerosHD
# Progress: 215/242 - EinfachEazy
# Progress: 216/242 - GingerTeddy
# Progress: 217/242 - Sower_
# Progress: 218/242 - Umgfoin
# Progress: 219/242 - Harold_Sensemann
# Progress: 220/242 - Lelouch610
# Progress: 221/242 - FrozenNoah
# Progress: 222/242 - D4rkCookie
# Progress: 223/242 - TheBreadHD
# Progress: 224/242 - RyanxCole
# Progress: 225/242 - SecretAgent_K
# Progress: 226/242 - frutigall
# Progress: 227/242 - y9nic
# Progress: 228/242 - Oronor
# Progress: 229/242 - BusinessBent
# Progress: 230/242 - Sthyq
# Progress: 231/242 - Kklopse
# Progress: 232/242 - kfc_man069
# Progress: 233/242 - Lennart0911
# Progress: 234/242 - JOW24
# Progress: 235/242 - Dokkkkko
# Progress: 236/242 - ffawks
# Progress: 237/242 - Luis_XYZ
# Progress: 238/242 - revolverz
# Progress: 239/242 - GrafikKatze
# Progress: 240/242 - Chander24
# Progress: 241/242 - Steavn
# Progress: 242/242 - HeIsJustAPoorBoy
# Warning: Keeping old name 'Freeeedom' - couldn't fetch current name
# Warning: Keeping old name 'JennieKim' - couldn't fetch current name
# Warning: Keeping old name 'Krusti' - couldn't fetch current name
# Warning: Keeping old name 'Lubottus' - couldn't fetch current name
# Warning: Keeping old name 'PedroZockt' - couldn't fetch current name
# Warning: Keeping old name 'Lutorix' - couldn't fetch current name
# Warning: Keeping old name '__egE' - couldn't fetch current name
# Warning: Keeping old name 'Tim_Voltia' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress: 100%|██████████| 242/242 [06:13<00:00,  1.54s/player, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
