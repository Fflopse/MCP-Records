# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:

            mp_stats = data['stats']['mp']['global']
            
            # Calculate win rates
            wins = mp_stats.get('wins', 0)
            games = mp_stats.get('games', 0)
            minigame_wins = mp_stats.get('minigame_wins', 0)
            minigames = mp_stats.get('minigames', 0)
            
            winrate = round((wins / games * 100), 2) if games > 0 else 0
            minigame_winrate = round((minigame_wins / minigames * 100), 2) if minigames > 0 else 0
            
            stat_mapping = {
                'Gewonnene Spiele': wins,
                'Gewonnene Minispiele': minigame_wins,
                'Gespielte Spiele': games,
                'Gespielte Minispiele': minigames,
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank', 0),
                'Winrate %': winrate,
                'Minigame Winrate %': minigame_winrate
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Processing 242 players...
# Found 242 unique UUIDs
# Progress: 1/242 - Pluto28
# Progress: 2/242 - DarkCobweb
# Progress: 3/242 - cheesecake2901
# Progress: 4/242 - JennieKim
# Progress: 5/242 - JOW23
# Progress: 6/242 - lizsyy
# Progress: 7/242 - Gummibearchen
# Progress: 8/242 - agowskyy
# Progress: 9/242 - yzvm
# Progress: 10/242 - RyanxCole
# Progress: 11/242 - Umgfoin
# Progress: 12/242 - _n3d
# Progress: 13/242 - sirmigorius
# Progress: 14/242 - lolisamasan
# Progress: 15/242 - Sthyq
# Progress: 16/242 - Acidey
# Progress: 17/242 - M0orey_0
# Progress: 18/242 - Luxemburq
# Progress: 19/242 - frutigall
# Progress: 20/242 - N3XV
# Progress: 21/242 - Cytoox
# Progress: 22/242 - Snitcherella
# Progress: 23/242 - Kopfradio
# Progress: 24/242 - GamemasterNiki
# Progress: 25/242 - Flitzi_Dino
# Progress: 26/242 - linastunna
# Progress: 27/242 - cxl1lo
# Progress: 28/242 - DaVinci_Son
# Progress: 29/242 - Lubottus
# Progress: 30/242 - destr0yed_
# Progress: 31/242 - Muniix
# Progress: 32/242 - Janne4k
# Progress: 33/242 - M0osebumps
# Progress: 34/242 - YBCM
# Progress: 35/242 - Hyxeed
# Progress: 36/242 - Juti0n
# Progress: 37/242 - MaxMitMaulkorb
# Progress: 38/242 - Keenaai
# Progress: 39/242 - OutcroYoutube
# Progress: 40/242 - __egE
# Progress: 41/242 - PumiTheCat
# Progress: 42/242 - Ritokii
# Progress: 43/242 - Chander24
# Progress: 44/242 - xd_Maiky
# Progress: 45/242 - WshPasie
# Progress: 46/242 - TheKillerisback
# Progress: 47/242 - BusinessBent
# Progress: 48/242 - T_Niko_T
# Progress: 49/242 - Raefinzs
# Progress: 50/242 - ZweitesIch
# Progress: 51/242 - Harold_Sensemann
# Progress: 52/242 - CML_Justin
# Error for UUID 1dc500f2-b39f-4971-82a9-e96d910aec44: HTTPSConnectionPool(host='sessionserver.mojang.com', port=443): Max retries exceeded with url: /session/minecraft/profile/1dc500f2-b39f-4971-82a9-e96d910aec44 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0
# Progress: 210/242 - camman18YT
# Progress: 211/242 - redbrll
# Progress: 212/242 - Tammywood
# Progress: 213/242 - Gryzes
# Progress: 214/242 - SatzdesPytag0ras
# Progress: 215/242 - xX_Masha_ggg_Xx9
# Progress: 216/242 - Picutar
# Progress: 217/242 - Failed to get name for 1786d729-a427-4351-8b34-e6dc3506af2b
# Progress: 218/242 - zLachs
# Progress: 219/242 - LordAlexos
# Progress: 220/242 - EinfachEazy
# Progress: 221/242 - xX_Dima_ggg_Xx6
# Progress: 222/242 - Bikoop
# Progress: 223/242 - Failed to get name for fc277870-ef7d-46b0-abb2-637a4358df8d
# Progress: 224/242 - Persidieus
# Progress: 225/242 - Mvsk_
# Progress: 226/242 - Joel_the_king
# Progress: 227/242 - chrisihalt
# Progress: 228/242 - Joy_8oy
# Progress: 229/242 - Highsay
# Progress: 230/242 - FlyingAutismus
# Progress: 231/242 - yiiq
# Progress: 232/242 - toxicplace
# Progress: 233/242 - WuschigesEtwas
# Progress: 234/242 - ScreamingBlatz
# Progress: 235/242 - Failed to get name for 7b540bd2-5ee4-4b51-b114-f905fd122558
# Progress: 236/242 - Tomiokey
# Progress: 237/242 - Martomias
# Progress: 238/242 - Failed to get name for 3e1295ed-b029-4403-b3c7-409eceba945c
# Progress: 239/242 - G0at3D
# Progress: 240/242 - Axollotel
# Progress: 241/242 - JOW24
# Progress: 242/242 - Failed to get name for bc71335b-1e4b-4a6d-a8e4-64862069790f
# Warning: Keeping old name 'MrNulfred' - couldn't fetch current name
# Warning: Keeping old name 'Gerrygames' - couldn't fetch current name
# Warning: Keeping old name 'Wissender' - couldn't fetch current name
# Warning: Keeping old name 'GeneralEnte06' - couldn't fetch current name
# Warning: Keeping old name 'La_meleagro' - couldn't fetch current name
# Warning: Keeping old name 'Sey__' - couldn't fetch current name
# Warning: Keeping old name 'ForceFox' - couldn't fetch current name
# Warning: Keeping old name 'Wienerisch' - couldn't fetch current name
# Warning: Keeping old name 'vKito' - couldn't fetch current name
# Warning: Keeping old name 'Lennart0911' - couldn't fetch current name
# Warning: Keeping old name '_Einfallslos_' - couldn't fetch current name
# Warning: Keeping old name 'Dat_Klan' - couldn't fetch current name
# Warning: Keeping old name 'JayMinInSane' - couldn't fetch current name
# Warning: Keeping old name 'AnzeigeGehtRaus' - couldn't fetch current name
# Warning: Keeping old name 'Bildungsarten' - couldn't fetch current name
# Warning: Keeping old name 'CladyNoClip_' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress:  50%|█████     | 122/242 [01:21<01:21,  1.47player/s, last_player=Nor_Malo, last_rank=Premium+]
