# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:

            mp_stats = data['stats']['mp']['global']
            
            # Calculate win rates
            wins = mp_stats.get('wins', 0)
            games = mp_stats.get('games', 0)
            minigame_wins = mp_stats.get('minigame_wins', 0)
            minigames = mp_stats.get('minigames', 0)
            
            winrate = round((wins / games * 100), 2) if games > 0 else 0
            minigame_winrate = round((minigame_wins / minigames * 100), 2) if minigames > 0 else 0
            
            stat_mapping = {
                'Siege': wins,
                'Minispiel-Siege': minigame_wins,
                'Spiele': games,
                'Minispiele': minigames,
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank', 0),
                'Winrate %': winrate,
                'Minigame Winrate %': minigame_winrate
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
# Warning: Keeping old name 'Feinberg' - couldn't fetch current name
# Warning: Keeping old name 'twitchparaskiill' - couldn't fetch current name
# Warning: Keeping old name 'Krusti' - couldn't fetch current name
# Warning: Keeping old name 'LeWi_100' - couldn't fetch current name
# Warning: Keeping old name 'ByNetherdude' - couldn't fetch current name
# Warning: Keeping old name 'SiLoHB' - couldn't fetch current name
# Warning: Keeping old name 'Dokkkkko' - couldn't fetch current name
# Warning: Keeping old name 'Jan2220' - couldn't fetch current name
# Warning: Keeping old name 'Kokochampo' - couldn't fetch current name
# Warning: Keeping old name 'PedroZockt' - couldn't fetch current name
# Warning: Keeping old name 'HerrDante' - couldn't fetch current name
# Warning: Keeping old name 'Fflopse' - couldn't fetch current name
# Warning: Keeping old name 'unausgesprochen' - couldn't fetch current name
# Warning: Keeping old name 'G0at3D' - couldn't fetch current name
# Warning: Keeping old name 'SecretAgent_K' - couldn't fetch current name
# Warning: Keeping old name 'Gfrasti' - couldn't fetch current name
# Warning: Keeping old name 'medisant' - couldn't fetch current name
# Warning: Keeping old name 'Mansuni' - couldn't fetch current name
# Warning: Keeping old name 'IchHolzDichWeg' - couldn't fetch current name
# Warning: Keeping old name 'Tammywood' - couldn't fetch current name
# Warning: Keeping old name 'NiklasMoWo' - couldn't fetch current name
# Warning: Keeping old name 'musi1999' - couldn't fetch current name
# Warning: Keeping old name 'FrozenNoah' - couldn't fetch current name
# Warning: Keeping old name 'ArthurAlchemist' - couldn't fetch current name
# Warning: Keeping old name 'Dubbly' - couldn't fetch current name
# Warning: Keeping old name 'yachayubin' - couldn't fetch current name
# Warning: Keeping old name 'KINT0' - couldn't fetch current name
# Warning: Keeping old name 'LucaaOn' - couldn't fetch current name
# Warning: Keeping old name 'Squashgitter333' - couldn't fetch current name
# Warning: Keeping old name 'BastiGHG' - couldn't fetch current name
# Warning: Keeping old name 'y9nic' - couldn't fetch current name
# Warning: Keeping old name 'FluffyDragon2007' - couldn't fetch current name
# Warning: Keeping old name 'Nervigerr' - couldn't fetch current name
# Warning: Keeping old name 'rotmann2' - couldn't fetch current name
# Warning: Keeping old name 'GingerTeddy' - couldn't fetch current name
# Warning: Keeping old name 'qriezmannsOpa' - couldn't fetch current name
# Warning: Keeping old name 'Lelouch610' - couldn't fetch current name
# Warning: Keeping old name 'xIForgotMySkill' - couldn't fetch current name
# Warning: Keeping old name 'Otronix' - couldn't fetch current name
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress: 100%|██████████| 242/242 [02:45<00:00,  1.47player/s, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
