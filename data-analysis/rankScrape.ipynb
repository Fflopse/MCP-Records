# %%
import requests
import json
import os
from tqdm import tqdm
import logging
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

keywords = ['Premium+', 'Premium', 'Bauteam', 'Spieler', 'Entwickler', 'VIP', 'Content', 'Supporter', 'Owner', 'Moderator', 'Translator']

player_data = {}
player_categories = {keyword: [] for keyword in keywords}

def fetch_player_data(player_name, log=False):
    url = f"https://api.cytooxien.de/user/{player_name}"
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        data = response.json()
        
        if log: 
            logging.info(f"Fetching API data for player: {player_name}")
        
        # Initialize player data structure
        player_data[player_name] = {
            "name": player_name,
            "rank": "None",
            "minecraft_party": {}
        }
        
        # Extract rank information
        if 'playerInfo' in data and 'rank' in data['playerInfo']:
            rank_name = data['playerInfo']['rank']['name']
            if rank_name in keywords:
                player_data[player_name]["rank"] = rank_name
                player_categories[rank_name].append(player_name)
                if log: 
                    logging.info(f"Player rank: {rank_name}")
            else:
                player_data[player_name]["rank"] = rank_name
        
        # Extract Minecraft Party data (mp stats)
        if 'stats' in data and 'mp' in data['stats'] and 'global' in data['stats']['mp']:
            mp_stats = data['stats']['mp']['global']
            
            # Map API fields to the format your original script expected
            stat_mapping = {
                'Siege': mp_stats.get('wins', 0),
                'Minispiel-Siege': mp_stats.get('minigame_wins', 0),
                'Spiele': mp_stats.get('games', 0),
                'Minispiele': mp_stats.get('minigames', 0),
                'Spielzeit': format_time(mp_stats.get('time', 0)),
                'Punkte': mp_stats.get('points', 0),
                'Rang': mp_stats.get('rank', 0)
            }
            
            player_data[player_name]["minecraft_party"] = stat_mapping
            
            if log: 
                logging.info("Found Minecraft Party data")
                for stat_name, stat_value in stat_mapping.items():
                    logging.info(f"Scraped: {stat_name} = {stat_value}")
        else:
            if log:
                logging.warning(f"No Minecraft Party data found for {player_name}")
        
        return player_data[player_name]["rank"]
        
    except requests.exceptions.RequestException as e:
        logging.error(f"Error fetching data for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"
    except json.JSONDecodeError as e:
        logging.error(f"Error parsing JSON for {player_name}: {e}")
        player_data[player_name] = {
            "name": player_name,
            "rank": "Error",
            "minecraft_party": {}
        }
        return "Error"

def format_time(milliseconds):
    # Convert milliseconds to a readable time format
    if milliseconds == 0:
        return "0"
    
    seconds = milliseconds // 1000
    minutes = seconds // 60
    hours = minutes // 60
    days = hours // 24
    
    if days > 0:
        return f"{days}d {hours % 24}h {minutes % 60}m"
    elif hours > 0:
        return f"{hours}h {minutes % 60}m"
    elif minutes > 0:
        return f"{minutes}m {seconds % 60}s"
    else:
        return f"{seconds}s"

# %%
import helpers as h
playerList = h.assemblePlayerList()

# Fetch data for all players with progress bar
progress_bar = tqdm(playerList, desc="Fetching Progress", unit="player")
for player_name in progress_bar:
    last_rank = fetch_player_data(player_name, log=False)
    progress_bar.set_postfix(last_rank=last_rank, last_player=player_name)
    time.sleep(0.1)  # Small delay to be respectful to the API

# Export data as JSON
with open('player_data.json', 'w', encoding='utf-8') as f:
    json.dump(player_data, f, ensure_ascii=False, indent=4)

print("Data exported to player_data.json")
# Out:
# Processing 242 players...
# Found 242 unique UUIDs
# Progress: 1/242 - Lord_Weibull
# Progress: 2/242 - Vacted
# Progress: 3/242 - xBaumeisterin
# Progress: 4/242 - N3XV
# Progress: 5/242 - DrSpeed06
# Progress: 6/242 - GamemasterNiki
# Progress: 7/242 - Flitzi_Dino
# Progress: 8/242 - CladyNoClip_
# Progress: 9/242 - Dat_Klan
# Progress: 10/242 - KakaMC
# Progress: 11/242 - musi1999
# Progress: 12/242 - Feinberg
# Progress: 13/242 - TheBreadHD
# Progress: 14/242 - Vanillinchen
# Progress: 15/242 - SmartyxD
# Progress: 16/242 - xd_Maiky
# Progress: 17/242 - Dokkkkko
# Progress: 18/242 - yiiq
# Progress: 19/242 - demiu
# Progress: 20/242 - agowskyy
# Progress: 21/242 - FlyingAutismus
# Progress: 22/242 - Chander24
# Progress: 23/242 - Ninivee
# Progress: 24/242 - cheesecake2901
# Progress: 25/242 - Joe3346
# Progress: 26/242 - Txlentierter
# Progress: 27/242 - Teesily
# Progress: 28/242 - GlowyDusk
# Progress: 29/242 - M0orey_0
# Progress: 30/242 - lolisamasan
# Progress: 31/242 - qriezmannsOpa
# Progress: 32/242 - xiooh
# Progress: 33/242 - JOW24
# Progress: 34/242 - EinfachEazy
# Progress: 35/242 - revolverz
# Progress: 36/242 - Schmaarek
# Progress: 37/242 - Picutar
# Progress: 38/242 - Tim_Voltia
# Progress: 39/242 - Seemops_8
# Progress: 40/242 - zBro
# Progress: 41/242 - Lennart0911
# Progress: 42/242 - DarkCobweb
# Progress: 43/242 - Krusti
# Progress: 44/242 - Tomiokey
# Progress: 45/242 - FluffyDragon2007
# Progress: 46/242 - NiklasMoWo
# Progress: 47/242 - DerAutist
# Progress: 48/242 - 2B9
# Progress: 49/242 - Gerrygames
# Progress: 50/242 - xX_Dima_ggg_Xx6
# Progress: 51/242 - TheFabo
# Progress: 52/242 - juvona
# Progress: 53/242 - Gummibearchen
# Progress: 54/242 - DieserBear
# Progress: 55/242 - y9nic
# Progress: 56/242 - Scuprum
# Progress: 57/242 - 20LeRe10
# Progress: 58/242 - vKito
# Progress: 59/242 - YBCM
# Progress: 60/242 - Nervigerr
# Progress: 61/242 - frutigall
# Progress: 62/242 - MoZadaTV
# Progress: 63/242 - sirmigorius
# Progress: 64/242 - KINT0
# Progress: 65/242 - h4nnes
# Progress: 66/242 - Lelouch610
# Progress: 67/242 - Mvsk_
# Progress: 68/242 - WshPasie
# Progress: 69/242 - Wienerisch
# Progress: 70/242 - Tammywood
# Progress: 71/242 - Kopfradio
# Progress: 72/242 - JOW23
# Progress: 73/242 - Juti0n
# Progress: 74/242 - Martomias
# Progress: 75/242 - StaudammAusHolz
# Progress: 76/242 - RyanxCole
# Progress: 77/242 - Gobo9
# Progress: 78/242 - ffawks
# Progress: 79/242 - Lutorix
# Progress: 80/242 - Carl1_1
# Progress: 81/242 - WirdNichtGeladen
# Progress: 82/242 - G0at3D
# Progress: 83/242 - Laaaachs
# Progress: 84/242 - Steavn
# Progress: 85/242 - MrNulfred
# Progress: 86/242 - SatzdesPytag0ras
# Progress: 87/242 - JennieKim
# Progress: 88/242 - GrafikKatze
# Progress: 89/242 - JayMinInSane
# Progress: 90/242 - GingerTeddy
# Progress: 91/242 - xIForgotMySkill
# Progress: 92/242 - WuschigesEtwas
# Progress: 93/242 - toxicplace
# Progress: 94/242 - medisant
# Progress: 95/242 - SpinCrafter
# Progress: 96/242 - Simlll
# Progress: 97/242 - KMaxN
# Progress: 98/242 - La_meleagro
# Progress: 99/242 - yzvm
# Progress: 100/242 - M0osebumps
# Progress: 101/242 - Stockinqs
# Progress: 102/242 - Mincheeen
# Progress: 103/242 - Luxemburq
# Progress: 104/242 - Joy_8oy
# Progress: 105/242 - BunnyKiko
# Progress: 106/242 - BauHD
# Progress: 107/242 - Kklopse
# Progress: 108/242 - OutcroYoutube
# Progress: 109/242 - Raefinzs
# Progress: 110/242 - SB387
# Progress: 111/242 - Ritokii
# Progress: 112/242 - __egE
# Progress: 113/242 - _Einfallslos_
# Progress: 114/242 - Jan2220
# Progress: 115/242 - Gryzes
# Progress: 116/242 - Axollotel
# Progress: 117/242 - PolizeiDreamy
# Progress: 118/242 - Sower_
# Progress: 119/242 - kfc_man069
# Progress: 120/242 - ZweitesIch
# Progress: 121/242 - Sey__
# Progress: 122/242 - LordAlexos
# Progress: 123/242 - Julius16
# Progress: 124/242 - GeneralEnte06
# Progress: 125/242 - twitchparaskiill
# Progress: 126/242 - shellny
# Progress: 127/242 - NotLennart
# Progress: 128/242 - Bikoop
# Progress: 129/242 - miridis41
# Progress: 130/242 - CML_Justin
# Progress: 131/242 - Wissender
# Progress: 132/242 - unausgesprochen
# Progress: 133/242 - Allooy
# Progress: 134/242 - T_Niko_T
# Progress: 135/242 - ByNetherdude
# Progress: 136/242 - Lubottus
# Progress: 137/242 - Sebi1801
# Progress: 138/242 - Nor_Malo
# Progress: 139/242 - Kokochampo
# Progress: 140/242 - jimmi4Life
# Progress: 141/242 - marbrueck
# Progress: 142/242 - Sthyq
# Progress: 143/242 - HerosHD
# Progress: 144/242 - Grapfen
# Progress: 145/242 - Dubbly
# Progress: 146/242 - BusinessBent
# Progress: 147/242 - Bildungsarten
# Progress: 148/242 - Pluto28
# Progress: 149/242 - Freeeedom
# Progress: 150/242 - _n3d
# Progress: 151/242 - Anni808
# Progress: 152/242 - BastiGHG
# Progress: 153/242 - Kanickelul
# Progress: 154/242 - byTobi
# Progress: 155/242 - Squashgitter333
# Progress: 156/242 - SpeckyCut
# Progress: 157/242 - Sackkerl
# Progress: 158/242 - cxl1lo
# Progress: 159/242 - ReichesBrot
# Progress: 160/242 - Oronor
# Progress: 161/242 - _Waldi_
# Progress: 162/242 - Phoenix3000
# Progress: 163/242 - Cytoox
# Progress: 164/242 - Muniix
# Progress: 165/242 - camman18YT
# Progress: 166/242 - PumiTheCat
# Progress: 167/242 - FlyingKyubi
# Progress: 168/242 - swiffle
# Progress: 169/242 - Persidieus
# Progress: 170/242 - LeWi_100
# Progress: 171/242 - Bartschii
# Progress: 172/242 - zLachs
# Progress: 173/242 - Ungluecklicher
# Progress: 174/242 - rotmann2
# Progress: 175/242 - LilFueller
# Progress: 176/242 - SecretAgent_K
# Progress: 177/242 - linastunna
# Progress: 178/242 - Umgfoin
# Progress: 179/242 - Wolkenfarmer
# Progress: 180/242 - cediiiiii_10
# Progress: 181/242 - Acidey
# Progress: 182/242 - PixlNight
# Progress: 183/242 - Falke_01
# Progress: 184/242 - LeMetin_
# Progress: 185/242 - Kyuudo
# Progress: 186/242 - crocodile1870
# Progress: 187/242 - Fflopse
# Progress: 188/242 - 2wc
# Progress: 189/242 - Hyxeed
# Progress: 190/242 - LucaaOn
# Progress: 191/242 - Shiewk
# Progress: 192/242 - Navex
# Progress: 193/242 - xX_Masha_ggg_Xx9
# Progress: 194/242 - Lingex
# Progress: 195/242 - Gestimus
# Progress: 196/242 - SiLoHB
# Progress: 197/242 - redbrll
# Progress: 198/242 - lolisamakun
# Progress: 199/242 - Harold_Sensemann
# Progress: 200/242 - destr0yed_
# Progress: 201/242 - Gfrasti
# Progress: 202/242 - IchHolzDichWeg
# Progress: 203/242 - bawskey
# Progress: 204/242 - FrozenNoah
# Progress: 205/242 - HerrDante
# Progress: 206/242 - MaxOnTheRoad
# Progress: 207/242 - Odlaa
# Progress: 208/242 - Joel_the_king
# Progress: 209/242 - GermanPie
# Progress: 210/242 - Falke23_5
# Progress: 211/242 - yachayubin
# Progress: 212/242 - dossantosaveiro_
# Progress: 213/242 - HeIsJustAPoorBoy
# Progress: 214/242 - DaVinci_Son
# Progress: 215/242 - NewNormal0947
# Progress: 216/242 - D4rkCookie
# Progress: 217/242 - VendasTM
# Progress: 218/242 - ArthurAlchemist
# Progress: 219/242 - Snitcherella
# Progress: 220/242 - Janne4k
# Progress: 221/242 - ScreamingBlatz
# Progress: 222/242 - Ex4cted
# Progress: 223/242 - lvlaurin
# Progress: 224/242 - Morittz
# Progress: 225/242 - AnzeigeGehtRaus
# Progress: 226/242 - PedroZockt
# Progress: 227/242 - lizsyy
# Progress: 228/242 - ForceFox
# Progress: 229/242 - Luis_XYZ
# Progress: 230/242 - TheKillerisback
# Progress: 231/242 - RasenLP
# Progress: 232/242 - MaxMitMaulkorb
# Progress: 233/242 - chrisihalt
# Progress: 234/242 - Mansuni
# Progress: 235/242 - deadfiight
# Progress: 236/242 - NanamiElvi
# Progress: 237/242 - Bikop
# Progress: 238/242 - SWLegende
# Progress: 239/242 - Keenaai
# Progress: 240/242 - Highsay
# Progress: 241/242 - Otronix
# Progress: 242/242 - loukrativ
#
# Update complete!
# Total players: 242
# Name changes detected: 0
# Updated data saved to: player_uuids.json
# Player name list saved to: player_names.txt
#
# Current player names (242 total):
#   20LeRe10
#   2B9
#   2wc
#   Acidey
#   Allooy
#   Anni808
#   AnzeigeGehtRaus
#   ArthurAlchemist
#   Axollotel
#   Bartschii
#   ... and 232 more
# Fetching Progress: 100%|██████████| 242/242 [02:29<00:00,  1.62player/s, last_player=zLachs, last_rank=Premium]
# Data exported to player_data.json
